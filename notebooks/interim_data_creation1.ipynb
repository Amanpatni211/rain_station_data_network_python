# %%
from pathlib import Path
current_path = Path.cwd()
print(f"Current working directory: {current_path}")
print("\nContents of current directory:")
for item in current_path.iterdir():
    print(f"- {item}")
# Out:
# Current working directory: /home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/Projects/rain_station_data_network_python/notebooks
#
# Contents of current directory:
# - /home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/Projects/rain_station_data_network_python/notebooks/interim_data_creation1.ipynb

# %%
import pkg_resources
installed_packages = [pkg.key for pkg in pkg_resources.working_set]
print("rain_station" in installed_packages)
# Out:
# False
# /tmp/ipykernel_42829/1942763185.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
import sys
print(sys.executable)
# Out:
# /home/udit/anaconda3/envs/rain_station_py/bin/python

# %%
import rain_station
print(rain_station.__file__)  # This will show where Python is finding the package
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rain_station
#       2 print(rain_station.__file__)  # This will show where Python is finding the package
#
# ModuleNotFoundError: No module named 'rain_station'

# %%
from pathlib import Path
from src.rain_station.data.interim_data_processor import SimpleStationProcessor

# Define paths (using absolute paths to be sure)
raw_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/raw")
interim_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/interim_Data")

# Create processor
processor = SimpleStationProcessor(raw_data_path, interim_data_path)

# Test with one file first
test_file = raw_data_path / "IN001010300.csv"
result = processor.process_station(test_file)
processor.save_station_data(result['metadata']['STATION'], result['data'])

print("Test file processed successfully!")

# If the test works, process all files
processor.process_all_stations()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 2
#       1 from pathlib import Path
# ----> 2 from src.rain_station.data.interim_data_processor import SimpleStationProcessor
#       4 # Define paths (using absolute paths to be sure)
#       5 raw_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/raw")
#
# ImportError: cannot import name 'SimpleStationProcessor' from 'src.rain_station.data.interim_data_processor' (/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/Projects/rain_station_data_network_python/src/rain_station/data/interim_data_processor.py)

# %%
from pathlib import Path
from src.rain_station.data.interim_data_processor import SimpleStationProcessor

# Define paths (using absolute paths to be sure)
raw_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/raw")
interim_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/interim_Data")

# Create processor
processor = SimpleStationProcessor(raw_data_path, interim_data_path)

# Test with one file first
test_file = raw_data_path / "IN001010300.csv"
result = processor.process_station(test_file)
processor.save_station_data(result['metadata']['STATION'], result['data'])

print("Test file processed successfully!")

# If the test works, process all files
processor.process_all_stations()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 from pathlib import Path
# ----> 2 from src.rain_station.data.interim_data_processor import SimpleStationProcessor
#       4 # Define paths (using absolute paths to be sure)
#       5 raw_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/raw")
#
# ImportError: cannot import name 'SimpleStationProcessor' from 'src.rain_station.data.interim_data_processor' (/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/Projects/rain_station_data_network_python/src/rain_station/data/interim_data_processor.py)

# %%
# Networks_rain_project/Projects/rain_station_data_network_python/notebooks/interim_data_creation1.ipynb

import sys
from pathlib import Path

# Add project root to Python path
project_root = Path("..").resolve()
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.rain_station.data.interim_data_processor import StationDataProcessor

# Define absolute paths
raw_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/raw")
interim_data_path = Path("/home/udit/Desktop/Data_MIR_students/PhD/Aman/Networks_rain_project/data/interim_Data")

# Verify paths
print(f"Raw data path exists: {raw_data_path.exists()}")
print(f"Raw data path: {raw_data_path.absolute()}")
print(f"Interim data will be saved to: {interim_data_path.absolute()}")

# Create processor and run
processor = StationDataProcessor(raw_data_path, interim_data_path)
processor.process_all_stations()
# Out:
# INFO:src.rain_station.data.interim_data_processor:Found 3807 station files to process
# INFO:src.rain_station.data.interim_data_processor:Processing station file: IN020012601.csv
# ERROR:src.rain_station.data.interim_data_processor:Error processing IN020012601.csv: Object of type int64 is not JSON serializable
# INFO:src.rain_station.data.interim_data_processor:Processing station file: IN023451100.csv
# ERROR:src.rain_station.data.interim_data_processor:Error processing IN023451100.csv: Object of type int64 is not JSON serializable
# INFO:src.rain_station.data.interim_data_processor:Processing station file: IN023550800.csv
# ERROR:src.rain_station.data.interim_data_processor:Error processing IN023550800.csv: Object of type int64 is not JSON serializable
# INFO:src.rain_station.data.interim_data_processor:Processing station file: IN004090600.csv
# ERROR:src.rain_station.data.interim_data_processor:Error processing IN004090600.csv: Object of type int64 is not JSON serializable
# ...

# %%
# Load metadata for a station
with open(interim_data_path / "metadata" / "IN001010100_meta.json") as f:
    metadata = json.load(f)

# Load time series data
data = np.load(interim_data_path / "timeseries" / "IN001010100_data.npz")
timeseries = dict(zip(data['dates'], data['values']))

# Load overall statistics
stats = pd.read_csv(interim_data_path / "station_statistics.csv")
